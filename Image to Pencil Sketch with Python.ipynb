# %% [markdown]
# ## Beginner level Task
#
# ## Task1- Image to Pencil Sketch with Python
# ## Shivam Bajpeyi
#
# ### LinkDin Profile ----> https://www.linkedin.com/in/shivam-bajpeyi/
#
# ### GitHub Profile ----> https://github.com/mayanksamadhiya12345¶

# %%
import cv2

# %% [markdown]
# ### reading the image

# %%
image = cv2.imread("Ganesha.jpg")
cv2.imshow("Image", image)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ![Ganesha.png](attachment:Ganesha.png)

# %% [markdown]
# ### converting image to grey scale

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow("Grey image", gray_image)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ![grey_scale.png](attachment:grey_scale.png)

# %% [markdown]
# ###  invert the new grayscale image

# %%
inverted_image = 255 - gray_image
cv2.imshow("Inverted Image", inverted_image)
cv2.waitKey()
# Out:
# -1

# %% [markdown]
# ![inverted-2.png](attachment:inverted-2.png)

# %% [markdown]
# ###  blur the image by using the Gaussian Function

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %% [markdown]
# ###  invert the blurred image

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2.imshow("Sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ![sketch-2.png](attachment:sketch-2.png)
